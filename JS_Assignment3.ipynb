# %% [markdown]
# 1. 1. In the following shopping cart add, remove, and edit items
#
#     => const shoppingCart = ['Milk', 'Coffee', 'Tea', 'Honey'O
# L      add 'Meat' in the beginning of your shopping cart if it has not been already addeJ
# L      add Sugar at the end of you shopping cart if it has not been already addeJ
# L      remove 'Honey' if you are allergic to hone
# L      modify Tea to 'Green Tea'
#
#     - const shoppingCart = ['Milk', 'Coffee', 'Tea', 'Honey']
#
#  if(!shoppingCart.includes('Meat')){
#     shoppingCart.unshift('Meat')//Meat at star
#  }
#
# if(!shoppingCart.includes('Sugar')){
#      shoppingCart.push('sugar');// sugar at end
# }
#
# //delelet honey
#
# let honeyIndex = shoppingCart.indexOf('Honey');
# if(honeyIndex !== -1){
#     shoppingCart.splice(honeyIndex,1);
# }
#
# //modify tea to green tea
#
# let teaIndex = shoppingCart.indexOf('Tea');
# if(teaIndex !== -1){
#     shoppingCart.splice(teaIndex,1,"Green Tea");
# }
#
# console.log(shoppingCart);

# %% [markdown]
# 2. The following is an array of 10 students ages:
#
#
#     => const ages = [19, 22, 19, 24, 20, 25, 26, 24, 25, 24O
# L     Sort the array and find the min and max age1
# L     Find the median age(one middle item or two middle items divided by twom
# L     Find the average age(all items divided by number of itemsm
# L     Find the range of the ages(max minus minm
# L     Compare the value of (min - average) and (max - average), use abs() method
#
#     - //sort
# const ages = [19, 22, 18, 24, 20, 25, 26, 24, 25, 24];
# ages.sort();
# console.log(ages);
#
# //min and max
#  let min = ages[0];
#  for(let i = 1; i<ages.length; i++){
#    if( ages[i]<min){
#     min = ages[i]
#    }
#  }
#  console.log("min age is", min)
#
#  //max value
# let max = ages[0];
# for(let i =1; i<ages.length; i++){
#     if(ages[i]>max){
#         max = ages[i];
#     }
# }
# console.log("max age is ", max)
#
# //median
#  let med1 = ages.length/2;
#  let med2 = (ages.length/2)-1;
#  console.log(`median1 is ${med1}, median2 is ${med2}`);
#  let median1 = ages[4];
#  let median2 = ages[5];
#  let median = (median1 + median2)/2;
#  console.log("median is ",median);
#
# // Average
#  let sum = 0;
# for(let i of ages){
#     sum += i
# }
# console.log(sum);
# const average = sum / ages.length;
# console.log("Average:" ,average);
#
#
#  //range
#
#  const range = max - min;
#  console.log("Min:", min);      // 18
# console.log("Max:", max);      // 26
#  console.log("Range:", range)
#
#  //abs()
#
#  const diffWithMin = Math.abs(average-min);
#  const diffWithMax = Math.abs(average-max);
#
# console.log("Difference with Min:", diffWithMin); // 20
# console.log("Difference with Max:", diffWithMax); // 20

# %% [markdown]
# 3.  Object Extensibility and Sealing
#
#
# a) Use the Object.preventExtensions method to prevent any further additions of properties to the student object.
#
# b) Use the Object.isExtensible method to check if the student object is extensible. Store the result in a variable
# called extensibleStatus.
#
# c) Create a new object called teacher with a 'subject' property set to 'Math'.
#
# d) Use the Object.seal method to seal the teacher object, preventing any additions or deletions of properties.
#
# e) Use the Object.isSealed method to check if the teacher object is sealed. Store the result in a variable called
# sealedStatus.
#
# f) Print the extensibleStatus and sealedStatus to the console.
#
#       - // a) Use the Object.preventExtensions method to prevent any further additions of properties to the student object.
#
# const student = {
#     name : "Alice",
#     age : 25
# }
#
# Object.preventExtensions(student); //preventing further property addition
# student.grade = "A"; //trying to add new property to the student object
#
# console.log(student); // here in output you will find grade property will not be added to the student object
#
#
# // b) Use the Object.isExtensible method to check if the student object is extensible. Store the result in a variable called extensibleStatus.
#
# const extensibleStatus = Object.isExtensible(student);
#
# // c) Create a new object called teacher with a 'subject' property set to 'Math'.
#
#  const teacher = {
#     name : "Aruna",
#     age: 30
#  }
#  const teacherProps = {
#     subject :{
#         value : 'Math',
#         enumerable : true ,
#         writable : true ,
#         configarable : true
#     }
#  }
#  const teacherObj = Object.create(teacher, teacherProps);
#
#  console.log(teacherObj);
#  console.log(teacherObj.name);
#  console.log(teacherObj.subject);
#
#
# // d) Use the Object.seal method to seal the teacher object, preventing any additions or deletions of properties.
#
# Object.seal(teacher);
#
#
# // e) Use the Object.isSealed method to check if the teacher object is sealed. Store the result in a variable called sealedStatus.
#
# const sealedStatus = Object.isSealed(teacher);
#
#
# // f) Print the extensibleStatus and sealedStatus to the console.
#
# console.log(`Student Object is Extensible? the ans is ${extensibleStatus}`);
# console.log(`Teacher object is sealed? the ans is ${sealedStatus}`);

# %% [markdown]
# 4. Assignment: Building a Student Management System
#
#
# Description:
#
# You are tasked with building a student management system using JavaScript. The system should allow you to
# perform various operations on a list of students, including adding, updating, deleting, and displaying student
# information.
#
#
# Requirements:
#
# Here is an initial array of students. Each student is represented as an object with the following properties: id,
# firstName, lastName, age, and grade.
# const students = [
#
#   { id: 1, firstName: "John", lastName: "Doe", age: 20, grade:
# "A" },
#
#   { id: 2, firstName: "Jane", lastName: "Smith", age: 22, grade:
# "B" },
#
#   { id: 3, firstName: "Bob", lastName: "Johnson", age: 19, grade:
# "A" },
#
#   // Add more students as needed
#
# ];
#         - const students = [
#
#   { id: 1, firstName: "John", lastName: "Doe", age: 20, grade: "A" },
#
#   { id: 2, firstName: "Jane", lastName: "Smith", age: 22, grade: "B" },
#
#   { id: 3, firstName: "Bob", lastName: "Johnson", age: 19, grade: "A" },
#
# ];
#
# // 1. to add new student to an array
#
# function addStudent(id, firstName, lastName, age, grade) {
#   const exists = students.some(student => student.id === id)
#   if (exists) {
#     console.log(`ID ${id} already exists. Please use another ID.`);
#     return students;
#   }
#   students.push({ id, firstName, lastName, age, grade });
#   console.log(` Student with ID ${id} added successfully.`);
#   return students;
# }
# addStudent(1, "Ray", "H", 25, "B");
# addStudent(5, "Roh", "G", 26, "A");
# console.log(students);
#
# // 2. Update Student Information: Create a function to update a student's information based on their id.
#
# function updateStudentInfo(id, newinfo) {
#   const index = students.findIndex(student => student.id === id);
#   if (index === -1) {
#     console.log(`Student ID ${id} does not exists`)
#   }
#   else {
#     students[index] = { ...students[index], ...newinfo };
#     console.log(`Student with ID ${id} updated successfully.`);
#     return students;
#   }
# }
#
# updateStudentInfo(3, { age: 23, grade: "A+", lastName: "Dsoza" });
# updateStudentInfo(6, { age: 23, grade: "A+", lastName: "Doe" });
#
# // 3. Delete a Student: Create a function to delete a student based on their id.
#
# function deleteStudent(id) {
#   const index = students.findIndex(student => student.id === id);
#   if (index === -1) {
#     console.log(`Student ID ${id} does not exists`)
#   }
#   else {
#     students.splice(index, 1);// 1 item from that index will be removed here
#     console.log(`Student ID ${id} deleted successfully`);
#     return students;
#   }
# }
#
# deleteStudent(1);
# console.log(students);
#
# // 4. List All Students: Create a function to display a list of all students.
#
# function listOfAllStudents() {
#   if (students.length === 0) {
#     console.log("No students found.");
#     return;
#   }
#   for (let student of students) {
#     console.log(`ID: ${student.id}, Name: ${student.firstName} ${student.lastName}, Age: ${student.age}, Grade: ${student.grade}`);
#   }
# }
#
# listOfAllStudents();
#
# // 5. Find Students by Grade: Create a function to find all students who have a specific grade.
#
# function studentsByGrade(grade) {
#   const matchedStudents = students.filter(student => student.grade === grade);
#
#   if (matchedStudents.length === 0) {
#     console.log(`The Grade ${grade} is not found`);
#     return;
#   }
#
#   for (let student of matchedStudents) {
#     console.log(`ID: ${student.id}, Name: ${student.firstName}`);
#   }
# }
# studentsByGrade("D")
# studentsByGrade("A");
#
# // 6. Calculate Average Age: Create a function to calculate the average age of all students using array method
#
# function avgAge() {
#   if (students.length === 0) {
#     console.log('No students are available');
#     return;
#   }
#   let sum = 0
#   for (let student of students) {
#     sum += student.age;
#   }
#   let average = sum / students.length;
#   console.log(`Average age of students is ${average}`);
#   return average;
# }
# avgAge();

# %% [markdown]
# 5. . You are given a JavaScript object representing a student's information. Your task is to use the 'for...in' loop
# to iterate over the properties of the object and perform various operations.
# const student = {
#
#   name: "Alice",
#
#   age: 22,
#
#   major: "Computer Science",
#
#   GPA: 3.8,
#
#   isEnrolled: true
#
# };
# a) Create a function displayStudentInfo that takes the student object as a parameter. Inside this function, use a
# 'for...in' loop to iterate over the properties of the student object and print each property and its corresponding
# value to the console. The output should look something like this:
# Property: name, Value: Alice
#
# Property: age, Value: 22
#
# Property: major, Value: Computer Science
#
# Property: GPA, Value: 3.8
# const student = {
#         name: "Alice",
#         age: 22,
#         major: "Computer Science",
#         GPA: 3.8,
#         isEnrolled: true
#     };
#
#     function displayStudentInfo( student){
#         for( let info in student){
#             console.log(`Property: ${info}, Value: ${student[info]}`)
#         }
#     }
#
#     displayStudentInfo(student);
#
# Property: isEnrolled, Value: true
#
#         -
